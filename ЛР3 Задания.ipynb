# %% [markdown]
# # Задание 1. Построение простого графика

# %% [markdown]
# ## Напишите код, который строит график функции y = x^2 на интервале [−10, 10].Добавьте заголовок, подписи осей и сетку

# %%
x = np.linspace(-10, 10, 50)
y = x**2
plt.plot(x,y)
plt.title("График функции y = x^2")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)

# %% [markdown]
# # Задание 2. Настройка стилей и цветов

# %% [markdown]
# ## Постройте три линии на одном графике:

# %% [markdown]
# ### y = x (синяя, пунктирная линия), <br> y = x^2 (зеленая, штрих-пунктирная линия), <br> y = x^3 (красная, сплошная линия).

# %% [markdown]
# ### Добавьте легенду и сделайте оси одинакового масштаба.

# %%
x = np.linspace(-1, 1, 50)
y1 = x
y2 = x**2
y3 = x**3
plt.plot(x, y1, c ='b', linestyle = '--', label = 'y = x')
plt.plot(x, y2, c ='g', linestyle = '-.', label = 'y = x^2')
plt.plot(x, y3, c ='r', linestyle = '-', label = 'y = x^3')
plt.grid(True)
plt.legend()
plt.axis('equal')
# Out:
# (-1.1, 1.1, -1.1, 1.1)

# %% [markdown]
# # Задание 3. Использование различных типов графиков

# %% [markdown]
# ## Сгенерируйте 50 случайных точек и постройте диаграмму рассеяния (scatter plot), где цвет точек зависит от их координаты по оси x, а размер точек зависит от координаты по оси y.

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x, y, c = x, s = y*100)
plt.title("Диаграмма рассеяния")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)

# %% [markdown]
# # Задание 4. Гистограмма распределения

# %% [markdown]
# ## Сгенерируйте 1000 случайных чисел из нормального распределения с параметрами μ = 0, σ = 1 и постройте их гистограмму с 30 бинами. Добавьте вертикальную линию в среднем значении.

# %%
xy = np.random.normal(loc = 0, scale = 1, size = 1000)
plt.hist(xy, bins = 30, edgecolor = "black")
sredn = np.mean(xy)
plt.axvline(sredn, color="red")
plt.title("Гистограмма распределения")
plt.grid(True)

# %% [markdown]
# # Задание 5. Столбчатая диаграмма

# %% [markdown]
# ## Создайте столбчатую диаграмму, которая показывает количество студентов, получивших оценки:

# %% [markdown]
# ### "Отлично" — 20 человек, <br> "Хорошо" — 35 человек, <br> "Удовлетворительно" — 30 человек, <br> "Неудовлетворительно" — 15 человек.

# %% [markdown]
# ### Добавьте подписи к осям и заголовок.

# %%
res = ["Отлично" , "Хорошо" , "Удовлетворительно" , "Неудовлетворительно"]
stud = [20, 35, 30, 15]
plt.bar(res, stud)
plt.title("Столбчатая диаграмма")
plt.xlabel("Оценка")
plt.ylabel("Количество студентов")
# Out:
# Text(0, 0.5, 'Количество студентов')

# %% [markdown]
# # Задание 6. Круговая диаграмма

# %% [markdown]
# ## Используя данные предыдущей задачи, постройте круговую диаграмму с процентными подписями секторов.

# %%
plt.pie(stud, labels = res, autopct = "%1.1f%%")
plt.title("Круговая диаграмма")
# Out:
# Text(0.5, 1.0, 'Круговая диаграмма')

# %% [markdown]
# # Задание 7. Трехмерный график поверхности

# %% [markdown]
# ## Используя mpl_toolkits.mplot3d , постройте 3D-график функции z = sin(√(x^2 + y^2)) на сетке значений x, y в диапазоне [−5, 5].

# %%
import mpl_toolkits.mplot3d
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))
siz = plt.figure(figsize = (5, 5))
tred = siz.add_subplot(111, projection = "3d")
graf = tred.plot_surface(x, y, z, cmap = "viridis")

# %% [markdown]
# # Задание 8. Множественные подграфики

# %% [markdown]
# ## Постройте четыре графика в одной фигуре (2 × 2 сетка):

# %% [markdown]
# ### 1. Линейный график y = x <br> 2. Парабола y = x^2 <br> 3. Синус y = sin(x) <br> 4. Косинус y = cos(x)

# %% [markdown]
# ### Добавьте заголовки к каждому подграфику.

# %%
x = np.linspace(-10, 10, 50)
siz, axes = plt.subplots(2, 2, figsize = (5, 5))
axes[0, 0].plot(x, x)
axes[0, 0].set_title("y = x")
axes[0, 0].grid(True)
axes[0, 1].plot(x, x**2)
axes[0, 1].set_title("$y = x^2$")
axes[0, 1].grid(True)
axes[1, 0].plot(x, np.sin(x))
axes[1, 0].set_title("$y = \\sin(x)$")
axes[1, 0].grid(True)
axes[1, 1].plot(x, np.cos(x))
axes[1, 1].set_title("$y = \\cos(x)$")
axes[1, 1].grid(True)

# %% [markdown]
# # Задание 9. Тепловая карта

# %% [markdown]
# ## Создайте случайную матрицу 10 × 10 с элементами от 0 до 1 и визуализируйте её как тепловую карту с цветовой шкалой.

# %%
tepl = np.random.rand(10, 10)
plt.figure(figsize=(5, 5))
tmap = plt.imshow(tepl)
plt.colorbar(tmap)
plt.title("Тепловая карта")
# Out:
# Text(0.5, 1.0, 'Тепловая карта')

# %% [markdown]
# # Индивидуальное задание

# %% [markdown]
# # Задание 1. Температурные изменения за сутки

# %% [markdown]
# ## Измерялась температура воздуха в течение дня:

# %% [markdown]
# ### Время суток (часы): [0, 3, 6, 9, 12, 15, 18, 21, 24] <br> Температура (°C): [-5, -6, -4, 2, 8, 12, 10, 3, -2]

# %% [markdown]
# ## Используйте разные цвета для температуры ниже и выше 0°C.

# %%
import matplotlib.pyplot as plt
import numpy as np
time = [0, 3, 6, 9, 12, 15, 18, 21, 24]
temp = [-5, -6, -4, 2, 8, 12, 10, 3, -2]
below_zero = [temp if temp < 0 else None for temp in temperatures]
above_zero = [temp if temp >= 0 else None for temp in temperatures]
plt.figure(figsize=(10, 6))
plt.plot(hours, below_zero, 'b-o', label='Температура < 0°C', linewidth=2, markersize=8)
plt.plot(hours, above_zero, 'r-o', label='Температура ≥ 0°C', linewidth=2, markersize=8)
plt.title("Температурные изменения")
plt.xlabel("Время суток")
plt.ylabel("Параметры температуры")
plt.xticks(hours)
plt.grid(True, linestyle='--', alpha=0.6)
plt.axhline(0, color='black', linestyle='-', linewidth=1)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Задание 2. Задача на построение столбчатых диаграмм  Matplotlib

# %% [markdown]
# ## Количество научных публикаций по областям знаний

# %% [markdown]
# ### Анализ количества публикаций за год:

# %% [markdown]
# ### Области: ['Математика', 'Физика', 'Биология', 'Химия', 'Компьютерные науки'] <br> Публикации: [120, 90, 150, 110, 180]
# ## Используйте диаграмму с горизонтальными столбцами и отметьте область с наибольшим количеством публикаций.

# %%
city = ["Математика" , "Физика" , "Биология" , "Химия" , "Компьютерные науки"]
tra = [120, 90, 150, 110, 180]
max_r = np.max(tra)
plt.figure(figsize=(8, 5))
bars = plt.bar(city, tra)
plt.axhline(y = max_r, color = 'r')
plt.title("Анализ кол-ва публикаций")
plt.xlabel("Области")
plt.ylabel("Публикации")
plt.show()

# %% [markdown]
# # Задание 3. Задача на вычисление определенного интеграла с помощью Matplotlib

# %% [markdown]
# ## В каждой задаче требуется:

# %% [markdown]
# ### 1. Построить график подинтегральной функции. <br> 2. Вычислить площадь под кривой на заданном отрезке как значение определенного интеграла.

# %% [markdown]
# ### Рассчитайте площадь под функцией: <br> на интервале [−2, 2].

# %% [markdown]
# ![Screenshot_4.png](attachment:2c22ee18-ae96-49ea-a804-0a30c9d87eac.png)

# %%
def f(x): return (2*x + 3)
x = np.linspace(-2, 2)
y = f(x)
dx = x[1] - x[0]
integ = np.trapz(y, x, dx)
plt.figure(figsize = (8, 5))
plt.plot(x, y)
plt.fill_between(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %% [markdown]
# # Задание 4. Задачи на построение 3D-графиков с помощью Matpolib

# %% [markdown]
# ## Экспоненциальный гребень

# %% [markdown]
# ### Постройте график:

# %% [markdown]
# ![Screenshot_6.png](attachment:44443ef0-c08e-4245-8ca1-52f42faabfc9.png)

# %% [markdown]
# ### на x, y ∈ [−3, 3]

# %%
from mpl_toolkits.mplot3d import Axes3D
x = np.linspace(-3, 3, 300)
y = np.linspace(-3, 3, 300)
X, Y = np.meshgrid(x, y)
Z = np.exp(-np.sqrt(X**2 + Y**2)) * np.cos(2 * np.pi * np.sqrt(X**2 + Y**2))
fig = plt.figure(figsize = (10, 7))
ax = fig.add_subplot(111, projection = '3d')
surf = ax.plot_surface(X, Y, Z, cmap = 'inferno')
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x, y)")
fig.colorbar(surf)
plt.show()
